# %%
import numpy as np

# %%
arr1 = [1,24,44,23,54]
arr2 = [23,46,76,65,53]

# %%
arr1 + arr2
# Out:
# [1, 24, 44, 23, 54, 23, 46, 76, 65, 53]

# %%
new = np.array(arr1)
old = np.array(arr2)

new + old
# Out:
# array([ 24,  70, 120,  88, 107])

# %%
new.shape #for size of an arr
# Out:
# (5,)

# %%
new.ndim              #for dimn. of arr
# Out:
# 1

# %%
new.mean()
# Out:
# np.float64(29.2)

# %%
new.max()
# Out:
# np.int64(54)

# %%
new.argmax()
# Out:
# np.int64(4)

# %%
np.random.permutation(new.size)         #random num import import krne liye
# Out:
# array([1, 0, 3, 2, 4], dtype=int32)

# %%
np.random.permutation(new.size)
# Out:
# array([1, 0, 4, 2, 3], dtype=int32)

# %%
ages = [21,43,54,25,53]
name = ["A1", "A2", "A3", "A4", "A5"]

ages = np.array(ages)
name = np.array(name)

ages.argsort()
# Out:
# array([0, 3, 1, 4, 2])

# %%
name[ages.argsort()]
# Out:
# array(['A1', 'A4', 'A2', 'A5', 'A3'], dtype='<U2')

# %%
np.random.randint(10,50)
# Out:
# 15

# %%
np.random.randint(10,50,3)
# Out:
# array([27, 10, 18], dtype=int32)

# %%
np.random.seed(7)
np.random.permutation(6)
# Out:
# array([3, 5, 0, 2, 1, 4], dtype=int32)
